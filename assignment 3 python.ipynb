# %%
import pandas as pd

# %% [markdown]
# a.	Load CSV in R by skipping second row.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Priyankk18k/IMDB-Data-set/master/IMDB_data.csv',skiprows=[2])

# %%
df.head()
# Out:
#                                                 Plot  \
# 0  Despite his tarnished reputation after the eve...
# 1  Based on the novel written by Stephen Chbosky,...
# 2  Mike Lane is a thirty-year old living in Tampa...
# 3  When Bond's latest assignment goes gravely wro...
# 4  Against medical advice and without the knowled...
#
#                              Title imdbVotes  \
# 0            The Dark Knight Rises      2679
# 1  The Perks of Being a Wallflower      1270
# 2                       Magic Mike      2580
# 3                          Skyfall      1807
# 4          Silver Linings Playbook      1828
#
#                                               Poster imdbRating  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTk4ODQz...         75
# 1  http://ia.media-imdb.com/images/M/MV5BMzIxOTQy...         71
# 2  http://ia.media-imdb.com/images/M/MV5BMTQzMDMz...         51
# 3  http://ia.media-imdb.com/images/M/MV5BMjAyODkz...         68
# ...

# %% [markdown]
# b.	Extract the unique genres and its count and store in data frame with index key.

# %%
unique_generes=df.Genre.value_counts()

# %%
df.columns
# Out:
# Index([u'Plot', u'Title', u'imdbVotes', u'Poster', u'imdbRating', u'Genre',
#        u'imdbID', u'Year', u'Language'],
#       dtype='object')

# %%
unique_generes
# Out:
# Drama                                                  689
# Comedy                                                 389
# Comedy, Drama                                          231
# Comedy, Drama, Romance                                 169
# Horror                                                 115
# Drama, Romance                                         105
# Comedy, Romance                                         77
# Drama, Thriller                                         74
# Horror, Thriller                                        68
# Crime, Drama, Thriller                                  61
# Drama, Family                                           53
# Action, Crime, Drama                                    49
# Crime, Drama                                            48
# Comedy, Drama, Family                                   43
# Action                                                  41
# Drama, Mystery, Thriller                                40
# ...

# %%
length=len(unique_generes)

# %%
df1=pd.DataFrame(unique_generes.to_frame().reset_index())

# %%
df1.head()
# Out:
#                     index  Genre
# 0                   Drama    689
# 1                  Comedy    389
# 2           Comedy, Drama    231
# 3  Comedy, Drama, Romance    169
# 4                  Horror    115

# %%
df1.columns=['Genre','Counts']

# %%
df1.head()
# Out:
#                     Genre  Counts
# 0                   Drama     689
# 1                  Comedy     389
# 2           Comedy, Drama     231
# 3  Comedy, Drama, Romance     169
# 4                  Horror     115

# %% [markdown]
# ##c.	Convert the required data types

# %%
df.shape
# Out:
# (3389, 9)

# %%
df.Plot=str(df['Plot'])

# %%
type(df.Plot)
# Out:
# pandas.core.series.Series

# %%
df.Title=str(df.Title)

# %%
df.indbID=str(df.imdbID)

# %% [markdown]
# ##d.	Sort the genre by its name

# %%
Sorted_genre=df.sort_values('Genre',inplace=True)

# %%
df
# Out:
#                                                    Plot  \
# 368   0       Despite his tarnished reputation after...
# 298   0       Despite his tarnished reputation after...
# 3315  0       Despite his tarnished reputation after...
# 1142  0       Despite his tarnished reputation after...
# 1257  0       Despite his tarnished reputation after...
# 1310  0       Despite his tarnished reputation after...
# 1614  0       Despite his tarnished reputation after...
# 1713  0       Despite his tarnished reputation after...
# 1844  0       Despite his tarnished reputation after...
# 2063  0       Despite his tarnished reputation after...
# 2084  0       Despite his tarnished reputation after...
# 227   0       Despite his tarnished reputation after...
# 2259  0       Despite his tarnished reputation after...
# 948   0       Despite his tarnished reputation after...
# 2282  0       Despite his tarnished reputation after...
# 2356  0       Despite his tarnished reputation after...
# ...

# %% [markdown]
# ##e.	Create new variable whose values should be square of difference between imdbrating and imdbvotes.

# %%
numcolumns = ['imdbVotes','imdbRating']
df[numcolumns]=df[numcolumns].apply(pd.to_numeric, errors ='coerce')

# %%
df['Difference']=((df.imdbRating) - (df.imdbVotes))**2

# %%
df.head()
# Out:
#                                                    Plot  \
# 368   0       Despite his tarnished reputation after...
# 298   0       Despite his tarnished reputation after...
# 3315  0       Despite his tarnished reputation after...
# 1142  0       Despite his tarnished reputation after...
# 1257  0       Despite his tarnished reputation after...
#
#                                                   Title  imdbVotes  \
# 368   0                                   The Dark K...     1084.0
# 298   0                                   The Dark K...     2672.0
# 3315  0                                   The Dark K...      803.0
# 1142  0                                   The Dark K...     1421.0
# 1257  0                                   The Dark K...     1887.0
#
#                                                  Poster  imdbRating   Genre  \
# 368   http://ia.media-imdb.com/images/M/MV5BODUyNDI1...        64.0  Action
# ...

# %%
df[numcolumns]
# Out:
#       imdbVotes  imdbRating
# 368      1084.0        64.0
# 298      2672.0        71.0
# 3315      803.0         6.5
# 1142     1421.0        68.0
# 1257     1887.0        54.0
# 1310     1887.0        54.0
# 1614     2718.0        87.0
# 1713     2718.0        87.0
# 1844     2718.0        87.0
# 2063     2718.0        87.0
# 2084     2718.0        87.0
# 227      2592.0        53.0
# 2259     2718.0        87.0
# 948      1559.0        63.0
# 2282     2718.0        87.0
# 2356     2718.0        87.0
# 2392     2718.0        87.0
# 3220      797.0         6.5
# 2525     2718.0        87.0
# 2528     2718.0        87.0
# 2538     2718.0        87.0
# 2559     2718.0        87.0
# 2587     2302.0        56.0
# 2618     2302.0        61.0
# 2675     2592.0        63.0
# 2803     1421.0        50.0
# 133      2718.0        87.0
# 3244        NaN         7.6
# 921      1887.0        58.0
# 241      2718.0        87.0
# ...         ...         ...
# 533      2718.0        87.0
# ...
